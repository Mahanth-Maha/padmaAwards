# %%
import pandas as pd
import numpy as np
from tqdm import tqdm
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)
import sweetviz as sv
def out(ver,data,sw=False):
    data.to_csv('renders/awards_v'+ver+'.csv')
    data.to_pickle('renders/awards_v'+ver+'.pickle')
    data.to_excel('renders/awards_v'+ver+'.xlsx')
    if sw:
        sv.analyze(data).show_html('renders/report_for_v'+ver+'.html')
awards = pd.read_pickle('renders/renders_awards_v1_03_05_persons_translated_Kaggle_out.pickle')

# %%
c = []
for i in awards.columns:
    if 'awards' in i and '\n' not in i and len(i) < 100:
        c.append(i)
# c
# print("awards_2 = pd.concat([awards['"+"']).combine_first(awards['".join(c) + "'])], axis=1)")

# %%
# df2 = pd.concat([df["A"], df["B"].combine_first(df["C"]).combine_first(df["D"])], axis=1)
# awards_2 = pd.concat([awards['Recipients'], awards["career"].combine_first(awards["hindi cinema career"]).combine_first(awards["career at l&t"]).combine_first(awards["career as a scientist"]).combine_first(awards["academic career"]).combine_first(awards["acting career"]).combine_first(awards["television career"]).combine_first(awards["early life and career"]).combine_first(awards["education and career"]).combine_first(awards["singing career"]).combine_first(awards["political and public career"]).combine_first(awards["managerial career"]).combine_first(awards["literary career"]).combine_first(awards["film career"]).combine_first(awards["writing career"]).combine_first(awards["early career"]).combine_first(awards["political career"]).combine_first(awards["career and recognition"]).combine_first(awards["early career and education"]).combine_first(awards["civil services career"]).combine_first(awards["coaching career"]).combine_first(awards["professional career"]).combine_first(awards["domestic career"]).combine_first(awards["career and legacy"]).combine_first(awards["military career"]).combine_first(awards["diplomatic and political career"]).combine_first(awards["career in usa"]).combine_first(awards["legal career"]).combine_first(awards["music career"]).combine_first(awards["life and career"]).combine_first(awards["bengali career"]).combine_first(awards["marathi career"]).combine_first(awards["early life, education and career"]).combine_first(awards["dance career"]).combine_first(awards["early political career (1947–1975)"]).combine_first(awards["career as a lawyer"]).combine_first(awards["rowing career"]).combine_first(awards["parliamentary career"]).combine_first(awards["musical career"]).combine_first(awards["career as professor"]).combine_first(awards["teaching career"]).combine_first(awards["painting career"]).combine_first(awards["early life and professional career"]).combine_first(awards["oju welfare association and social career"]).combine_first(awards["career as a journalist and social reformer"]).combine_first(awards["playing career"]).combine_first(awards["career highlights and exhibitions"]).combine_first(awards["diplomatic career"]).combine_first(awards["swimming career"]).combine_first(awards["civil service career"]).combine_first(awards["later career"]).combine_first(awards["early life and military career"]).combine_first(awards["education and professional career"]).combine_first(awards["his career"]).combine_first(awards["life and early career"]).combine_first(awards["style and career"]).combine_first(awards["football career"]).combine_first(awards["cricket career"]).combine_first(awards["scholarly career"]).combine_first(awards["career highlights"]).combine_first(awards["political and social career"]).combine_first(awards["international career"]).combine_first(awards["career as a college professor"]).combine_first(awards["senior career"]).combine_first(awards["performing career"]).combine_first(awards["career as musician"]).combine_first(awards["government career"]).combine_first(awards["early domestic career"]).combine_first(awards["test career"]).combine_first(awards["early life, education, and early political career"]).combine_first(awards["rashtriya seva samithi and social career"]).combine_first(awards["early life, education, and early career"]).combine_first(awards["research career"]).combine_first(awards["work and career"]).combine_first(awards["government and diplomatic career"]).combine_first(awards["business career"]).combine_first(awards["social career"]).combine_first(awards["career and highlights"]).combine_first(awards["sporting career"]).combine_first(awards["tennis career"]).combine_first(awards["early judicial career"]).combine_first(awards["post-judicial career"]).combine_first(awards["dancing career"]).combine_first(awards["career and philanthropy"]).combine_first(awards["mountaineering career highlights"]).combine_first(awards["army career"]).combine_first(awards["remaining career"]).combine_first(awards["career as scriptwriter"]).combine_first(awards["european tour professional career summary"]).combine_first(awards["professional athletics career"]).combine_first(awards["career as surgeon"]).combine_first(awards["career beginnings"]).combine_first(awards["engineering career"]).combine_first(awards["boxing career"]).combine_first(awards["hindustani music career"]).combine_first(awards["academic and professional career"]).combine_first(awards["literary and social career"]).combine_first(awards["non-singing career"]).combine_first(awards["atp career finals"]).combine_first(awards["performing and recording career"]).combine_first(awards["scientific career"]).combine_first(awards["career graph"]).combine_first(awards["training and career"]).combine_first(awards["career and research"]).combine_first(awards["cricketing career"]).combine_first(awards["athletic career"]).combine_first(awards["journalistic career"]).combine_first(awards["career milestones and honours"]).combine_first(awards["career and influences"]).combine_first(awards["broadcasting career"]).combine_first(awards["youth and domestic career"]).combine_first(awards["early career in mumbai (then bombay)"]).combine_first(awards["recording career in the 1950s and 1960s"]).combine_first(awards["district administration career"]).combine_first(awards["post ias career"]).combine_first(awards["early life - career"]).combine_first(awards["journalism and career"]).combine_first(awards["theatre career"]).combine_first(awards["legislative career"]).combine_first(awards["education and early career"]).combine_first(awards["family background and early career"]).combine_first(awards["formula one career"]).combine_first(awards["career as architect"]).combine_first(awards["naval career"]).combine_first(awards["career in anthropology"]).combine_first(awards["career highlights and legacy"]).combine_first(awards["early life and club career"]).combine_first(awards["career statistics"]).combine_first(awards["post-air force career"]).combine_first(awards["personal life and career"]).combine_first(awards["career in department of atomic energy"]).combine_first(awards["career with bhabha atomic research centre"]).combine_first(awards["career overview"]).combine_first(awards["photography career"]).combine_first(awards["billiards career"]).combine_first(awards["snooker career"]).combine_first(awards["first-class career"]).combine_first(awards["career and achievements"]).combine_first(awards["career as an artist"]).combine_first(awards["education & career"]).combine_first(awards["bodybuilding career"]).combine_first(awards["hockey career"]).combine_first(awards["media career"]).combine_first(awards["skydiving career"]).combine_first(awards["formative years and domestic career"]).combine_first(awards["political and business career"]).combine_first(awards["bollywood career"]).combine_first(awards["sports career"]).combine_first(awards["atp tour career finals"]).combine_first(awards["education and academic career"]).combine_first(awards["career highlights and achievements"]).combine_first(awards["ila trust and social career"]).combine_first(awards["career and honours"]).combine_first(awards["creative career"]).combine_first(awards["art career"]).combine_first(awards["medical career"]).combine_first(awards["post playing career"]).combine_first(awards["club career"]).combine_first(awards["bharatanatyam career"]).combine_first(awards["career in film direction"]).combine_first(awards["career – dancing duo"]).combine_first(awards["career positions held"]).combine_first(awards["achievements in dance career"]).combine_first(awards["artistic career"]).combine_first(awards["administration career"]).combine_first(awards["overall career performance"]).combine_first(awards["career and political activism"]).combine_first(awards["umpiring career"]).combine_first(awards["career as a scholar and a philosopher"]).combine_first(awards["after playing career"]).combine_first(awards["entertainment career"]).combine_first(awards["career in nasa"]).combine_first(awards["advocacy career"]).combine_first(awards["career and writing style"]).combine_first(awards["music and career"]).combine_first(awards["later career and life"]).combine_first(awards["early life and initial career struggles"]).combine_first(awards["shooting career"]).combine_first(awards["amateur boxing career"]).combine_first(awards["professional career as an ophthalmologist"]).combine_first(awards["literary career and success"]).combine_first(awards["post-united nations career"]).combine_first(awards["early chess career"]).combine_first(awards["post-2010 chess career"]).combine_first(awards["conducting career"]).combine_first(awards["career Telugu"])], axis=1)
awards_2 = pd.concat([awards['Recipients'],awards['awards & honors'].combine_first(awards['awards']).combine_first(awards['awards and honours']).combine_first(awards['awards and recognitions']).combine_first(awards['works and awards']).combine_first(awards['awards and recognition']).combine_first(awards['awards and accolades']).combine_first(awards['awards and professional recognition']).combine_first(awards['awards and milestones']).combine_first(awards['honours and awards']).combine_first(awards['awards and honors']).combine_first(awards['awards and nominations']).combine_first(awards['selected awards and honours']).combine_first(awards['honors and awards']).combine_first(awards['honours, awards and international recognition']).combine_first(awards['awards and decorations']).combine_first(awards['awards and associations']).combine_first(awards['awards and medals']).combine_first(awards['fellowships and awards']).combine_first(awards['awards, honors, and fellowships']).combine_first(awards['international awards']).combine_first(awards['national awards']).combine_first(awards['awards and distinctions']).combine_first(awards['awards, etc']).combine_first(awards['awards and legacy']).combine_first(awards['positions and awards']).combine_first(awards['legacy and awards']).combine_first(awards['awards and titles']).combine_first(awards['awards & honours']).combine_first(awards['awards, honours and recognitions']).combine_first(awards['awards & recognitions']).combine_first(awards['recognition and awards']).combine_first(awards['awards, honours and recognition']).combine_first(awards['awards and achievements']).combine_first(awards['honors & awards']).combine_first(awards['awards and international honours']).combine_first(awards['awards and memberships of technological committees']).combine_first(awards['awards instituted in his memory']).combine_first(awards['major awards']).combine_first(awards['achievements and awards']).combine_first(awards['awards, honors and commentary']).combine_first(awards['"padma awards list". indian panorama. 2014. retrieved 12 october 2014.']).combine_first(awards['awards and contribution']).combine_first(awards['awards, recognition and legacy']).combine_first(awards['research awards']).combine_first(awards['awards, honors and titles']).combine_first(awards['awards and felicitations']).combine_first(awards['awards, honors, and recognition']).combine_first(awards['awards, titles and tributes']).combine_first(awards['notable awards and positions held']).combine_first(awards['awards, fellowships and honors']).combine_first(awards['awards and later life']).combine_first(awards['publications and awards']).combine_first(awards['awards - recipient of award of "padma shri" in 1969.']).combine_first(awards['awards, titles and honours']).combine_first(awards['awards received']).combine_first(awards['awards and death']).combine_first(awards['notable awards']).combine_first(awards['dance and awards']).combine_first(awards['legacy, awards and recognitions']).combine_first(awards['film awards']).combine_first(awards['other awards and recognition']).combine_first(awards['awards and achievement']).combine_first(awards['awards and honros']).combine_first(awards['position held and awards']).combine_first(awards['recognition, awards and honours']).combine_first(awards['list of indian winners and nominees of the academy awards']).combine_first(awards['honors, awards, and other recognitions']).combine_first(awards['awards, honors and positions']).combine_first(awards['selected honors and awards']).combine_first(awards['awards, honours, and recognition']).combine_first(awards['honours, awards and recognition']).combine_first(awards['awards and honour']).combine_first(awards['filmography and awards']).combine_first(awards['honors, awards and international recognition']).combine_first(awards['awards,honors and recognitions']).combine_first(awards['mukherjee has won several awards including:']).combine_first(awards['awards and doctorates']).combine_first(awards['awards and records']).combine_first(awards['organizational awards']).combine_first(awards['awards won']).combine_first(awards['key awards and distinctions']).combine_first(awards['karnataka state film awards']).combine_first(awards['awards (academic) and national honours']).combine_first(awards['awards, rewards and recognition']).combine_first(awards['awards & honors Telugu'])], axis=1)

# %%
print(sum(pd.isna(awards_2['awards & honors'])))
print(sum(pd.isna(awards['awards & honors'])))
# Out:
# 3000
# 4447

# %%
# ~pd.isna(awards['career'])
# Out:
# 0        True
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4444    False
# 4445     True
# 4446    False
# 4447     True
# 4448    False
# Name: career, Length: 4449, dtype: bool

# %%
k = sv.analyze(awards)
k.show_html('renders/renders_awards_v1_03_05_persons_translated_Kaggle_out.html')
# Out:
# [Summarizing dataframe]                      |          | [  0%]   00:02 -> (1:54:06 left)
# PAIRWISE CALCULATION LENGTH WARNING: There are 2903 features in this dataframe and the 'pairwise_analysis' parameter is set to 'auto'.
# Pairwise analysis is exponential in length: 2903 features will cause ~8427409 pairs to be evaluated, which could take a long time.
#
# You must call the function with the parameter pairwise_analysis='on' or 'off' to explicitly select desired behavior.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\LEGION\Documents\padmaAwards\src\Clean_02_Clear_redundant_data.ipynb Cell 3' in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/Users/LEGION/Documents/padmaAwards/src/Clean_02_Clear_redundant_data.ipynb#ch0000002?line=0'>1</a> k = sv.analyze(awards)
# ...

# %%
rem_lis = []
for i in awards.columns:
    if sum(~pd.isna(awards[i])) > 4*awards.shape[0]//100:
        # print(i,sum(pd.isna(awards[i])))
        pass
    else:
        rem_lis.append(i)
rem_lis
# Out:
# ['awards & honors',
#  'life',
#  'hindi cinema career',
#  'health and financial issues',
#  'freedom fighter',
#  'works',
#  'contributions to indian studies',
#  'controversy regarding his essay',
#  'selected publications',
#  'guillermo rodriguez, when mirrors are windows: a view of ak ramanujan’s poetics  ( oup, 2016)',
#  'profile',
#  'teaching',
#  'textbooks',
#  'career at l&t',
#  'chairman – nsdc',
#  'philanthropy',
#  'career as a scientist',
#  'presidency',
#  'post-presidency',
#  'religious and spiritual views',
#  'writings',
# ...

# %%
k = ['awards & honors','life','freedom fighter','awards and honors','award']
for i in k:
    rem_lis.remove(i)

# %%
len(rem_lis)
# Out:
# 2878

# %%
awards.drop(columns=rem_lis,inplace=True)
len(awards.columns)
# Out:
# 25

# %%
out('2_0_1',awards,True)
# Out:
# [Step 3/3] Generating associations graph     |          | [  0%]   00:00 -> (? left)    C:\Users\LEGION\anaconda3\envs\indicwiki\lib\site-packages\sweetviz\graph_associations.py:223: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_dataframe = new_dataframe.append(pd.Series(empty_row_dict, name=feature))
# Done! Use 'show' commands to display/save.   |██████████| [100%]   00:01 -> (00:00 left)
# Report renders/report_for_v2_0_1.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %%
awards_new = pd.read_csv('renders/awards_v2_0_1_load.csv')

# %%
awards_new.drop(columns=['Unnamed: 0'],inplace=True)
awards = pd.read_csv('renders/awards_v1_03.csv')
awards.drop(columns=['Unnamed: 0'],inplace=True)

# %%
data = pd.merge(awards,awards_new,on='Recipients')
data.head(10)
# Out:
#                    Recipients                                           WikiLink  Padma Shri Year       Padma Shri State          Padma Shri Field Padma Shri Awarded By  Padma Bhushan Year Padma Bhushan State       Padma Bhushan Field Padma Bhushan Awarded By  Padma Vibhushan Year Padma Vibhushan State Padma Vibhushan Field Padma Vibhushan Awarded By                                               Born                       Birth Date                                 Place of Birth                                               Died                           Death Date                   Place of Death Nationality      Spouse Alma mater Institutions                       Other Awards including Padma                        Occupation Election Year Posthumus                                            Summary                                    awards & honors                                             career                                         references  \
# ...

# %%
print(awards_new.shape[0])
print(awards.shape[0])
print(data.shape[0])
# Out:
# 4449
# 4449
# 4451

# %%
out('3_01',data,True)
# Out:
# Feature: Padma Shri State                    |▊         | [  9%]   00:00 -> (00:08 left)C:\Users\LEGION\anaconda3\envs\indicwiki\lib\site-packages\sweetviz\utils.py:34: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   clamped_series = clamped_series.append(other_series, ignore_index=False)
# C:\Users\LEGION\anaconda3\envs\indicwiki\lib\site-packages\sweetviz\utils.py:34: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   clamped_series = clamped_series.append(other_series, ignore_index=False)
# C:\Users\LEGION\anaconda3\envs\indicwiki\lib\site-packages\sweetviz\utils.py:34: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   clamped_series = clamped_series.append(other_series, ignore_index=False)
# ...
